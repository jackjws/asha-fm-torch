# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
capture = cv2.VideoCapture('/content/drive/MyDrive/VISUALS/SELECTED VISUALS FOR SITE/Red_Glitch_2.mov')

# %%
frameCount = 0

# %%
while (True):
    success, frame = capture.read()
    if success:
        cv2.imwrite(f'/content/drive/MyDrive/CODE/Split Frames/{frameCount}.jpg', frame)
    else:
        break
 
    frameCount = frameCount+1

capture.release()
