# %% [markdown]
# # Start to Finish

# %% [markdown]
# # Imports

# %%
# %matplotlib inline
import librosa, librosa.display
import numpy as np
import random 
import os
import matplotlib.pyplot as plt
import math
#from spleeter.separator import Separator

import moviepy.editor as mp
from PIL import Image
from datetime import datetime

start = datetime.now()

# %%
np.set_printoptions(linewidth=10000, suppress=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %% [markdown]
# # Params

# %%
DRUM_AUDIO_PATH = '/content/drive/MyDrive/Asha FM/raw_data/audio/mungolong.mp3'
audio_path = '/content/drive/MyDrive/Asha FM/raw_data/audio/mungolong.mp3'
AUDIO_FILE_NAME = 'AUDIO_FILE'
RAW_AUDIO_PATH = '/content/drive/MyDrive/Asha FM/raw_data/audio/mungolong.mp3'

# %%
# IO
# AUDIO_FILE_NAME = RAW_AUDIO_PATH.split('/')[-1].split('.')[0]

# SPLIT_AUDIO_PATH = f"../raw_data/audio/{AUDIO_FILE_NAME}/"
# DRUM_AUDIO_PATH = f"{SPLIT_AUDIO_PATH}{AUDIO_FILE_NAME}-drums.wav"

VIDEO_SAVE_NAME = f"{AUDIO_FILE_NAME}-asha.mp4"
VIDEO_SAVE_PATH = f"../outputs/{VIDEO_SAVE_NAME}"

# GLOBAL
# FIXED DURATION

# AUDIO 
FRAME_RATE = 60
HOP_WINDOW = 512

# Images
IMAGE_TIME_GAP = 1 # seconds, play with this
IMAGE_FRAME_GAP = IMAGE_TIME_GAP * FRAME_RATE

# VIDEO
MAX_VIDEO_DURATION = 19

# %% [markdown]
# # Audio

# %% [markdown]
# ## Split the Audio into stems
#
# With spleeter by deezer

# %%
# seperator = Separator(params_descriptor='spleeter:4stems')

# seperator.separate_to_file(
#     RAW_AUDIO_PATH, 
#     SPLIT_AUDIO_PATH,
#     duration=MAX_VIDEO_DURATION,
#     filename_format="{filename}-{instrument}.{codec}"
# )

# %% [markdown]
# ## Extracting Audio info from drum stem

# %% [markdown]
# ### Extraction functions

# %%
def get_audio_params(audio_path):
    # Load song with 22050 sample rate
    y, sr = librosa.load(audio_path, sr=22050)
    audio_duration = librosa.get_duration(y=y, sr=sr)
    
    total_frames_float = audio_duration * FRAME_RATE
    total_frames = math.ceil(total_frames_float)
    
    sample_rate = round(total_frames_float / audio_duration * HOP_WINDOW)
    
    return total_frames, sample_rate, audio_duration

# %%
def get_onset_info(audio_path, sample_rate):
    # Load
    y, sr = librosa.load(audio_path, sr=sample_rate)
    
    # Onset strengths and normalize
    onset_strengths = librosa.onset.onset_strength(y=y, sr=sample_rate, aggregate=np.median)
    onset_strengths = librosa.util.normalize(onset_strengths)
    
    # Onset timestamps and frames
    onset_times = librosa.times_like(onset_strengths, sr=sample_rate)
    onset_frames = onset_times * FRAME_RATE
    
    onset_info = np.concatenate([
        onset_frames.reshape((-1, 1)),
        onset_times.reshape((-1, 1)),
        onset_strengths.reshape((-1, 1))
    ], axis=1)
    
    # Beat times
    beat_times = librosa.beat.beat_track(y=y, sr=sample_rate, units='time')[1]
    
    return y, onset_info, beat_times

# %% [markdown]
# ### Using those functions

# %%
total_frames, sample_rate, audio_duration = get_audio_params(DRUM_AUDIO_PATH)
total_frames, sample_rate, audio_duration

# %%
y, onset_info, beat_times = get_onset_info(DRUM_AUDIO_PATH, sample_rate)
y.shape, onset_info.shape, beat_times.shape

# %%
onset_info

# %%
plt.plot(onset_info[:,1], onset_info[:,2])
plt.vlines(beat_times, ymin=0, ymax=1, colors='r', linestyles='--')
plt.show()

# %% [markdown]
# ## Create additional onset strength features
#
# - Linear Decay
# - Exponential Decay

# %%
def create_onset_features(onset_info, beat_times, lin_decay_time=0.25, exp_decay_rate=0.25, decay_magnification=True):
    
    fixed_decay_frames = int(lin_decay_time * FRAME_RATE)
    
    # Create column of zeroes as default value for both Linear and Exp Decay
    onset_info = np.concatenate([onset_info, np.zeros((onset_info.shape[0], 1)), np.zeros((onset_info.shape[0], 1))], axis=1)
    
    # for each row
    for i in range(onset_info.shape[0]):
        # Skip the first value, makes life easy
        if i == 0:
            onset_info[i, 3] = 0
        
        
        ## LINEAR
        # If the timestamp is in beat_times, it's a peak
        if onset_info[i, 1] in beat_times:
            onset_info[i, 3] = onset_info[i, 2] # Linear Column
            
            # Decay Params
            decay_factor = 1
            if decay_magnification:
                decay_factor *= (onset_info[i, 2] + 1)
            
            decay_frames = fixed_decay_frames * decay_factor
            lin_decay_val = onset_info[i, 2] / decay_frames
        
        # Check if the previous value is zero or less than the decay_val -> 0
        if onset_info[i - 1, 3] == 0. or abs(onset_info[i -1, 3]) < lin_decay_val:
            pass
        
        # If previous value > 0, needs decay
        elif onset_info[i - 1, 3] > 0: 
            onset_info[i, 3] = onset_info[i - 1, 3] - lin_decay_val
        
        
        # EXPONENTIAL
        # If the timestamp is in beat_times, it's a peak
        if onset_info[i, 1] in beat_times:
            onset_info[i, 4] = onset_info[i, 2] # Exp Column
        
        # Set current to zero if previous is zero or small number
        elif onset_info[i - 1, 4] == 0 or onset_info[i - 1, 4] < 0.005: 
            pass
        
        # If previous value > 0, needs decay
        elif onset_info[i - 1, 4] != 0: 
                onset_info[i, 4] = onset_info[i - 1, 4] * (1 - exp_decay_rate)
    
    return onset_info

# %%
y, onset_info, beat_times = get_onset_info(DRUM_AUDIO_PATH, sample_rate)
onset_info = create_onset_features(onset_info, beat_times, lin_decay_time=0.25, exp_decay_rate=0.25, decay_magnification=False)

# %%
# Visualising

fig, ax = plt.subplots(nrows=1, ncols=3)

fig.set_figheight(5)
fig.set_figwidth(15)

ax[0].plot(onset_info[:,1], onset_info[:,2])
# ax[0].vlines(beat_times, ymin=0, ymax=1, colors='r', linestyles='--')
ax[1].plot(onset_info[:,1], onset_info[:,3])
# ax[1].vlines(beat_times, ymin=0, ymax=1, colors='r', linestyles='--')
ax[2].plot(onset_info[:,1], onset_info[:,4])
# ax[2].vlines(beat_times, ymin=0, ymax=1, colors='r', linestyles='--')

plt.show()

# %% [markdown]
# # Model Stuff

# %%
import numpy as np
from PIL import Image
import os

import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.layers import Input, Reshape, Conv2D, Conv2DTranspose, Dense, Flatten, MaxPooling2D
from tensorflow.keras.utils import image_dataset_from_directory

# %%
filename = "/content/drive/MyDrive/Asha FM/raw_data/images/encoded_images.npy"

def load_images_from_file(filename):
    latent_space = np.load(filename)
    return latent_space

# %%
encoded_images = load_images_from_file("/content/drive/MyDrive/Asha FM/raw_data/images/encoded_images.npy")

# %%
encoded_images.shape
# Out:
# (2355, 200)

# %% [markdown]
# ### Model Architecture
#
# Because we are using load weights, we need to instantiate the model every time. This sucks for notebooks, but it will be fine once everything is packaged.

# %%
class Sampling(tf.keras.layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
latent_dim = 200

## Encoder

input_image = Input(shape=(448, 448, 3))
    
x = Conv2D(32, (3, 3), padding='same', activation="relu")(input_image)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(64, (3, 3), padding='same', activation="relu")(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(128, (3, 3), padding='same', activation="relu")(x)
x = MaxPooling2D((2, 2))(x)

x = Conv2D(256, (3, 3), padding='same', activation="relu")(x)
x = MaxPooling2D((2, 2))(x)

x = Flatten()(x)

z_mean = Dense(latent_dim, name="z_mean")(x)
z_log_var = Dense(latent_dim, name="z_log_var")(x)

z = Sampling()([z_mean, z_log_var])

# Encoder Build
encoder = Model(input_image, [z_mean, z_log_var, z], name="encoder")

#############################################

## Decoder

latent_inputs = Input(shape=(latent_dim,))  
y = Dense(7*7*128, activation='tanh')(latent_inputs)
y = Reshape((7, 7, 128))(y)

y = Conv2DTranspose(256, (3, 3), strides=2, padding='same', activation="relu")(y)
y = Conv2DTranspose(256, (3, 3), strides=1, padding='same', activation="relu")(y)
y = Conv2DTranspose(256, (3, 3), strides=1, padding='same', activation="relu")(y)
y = Conv2DTranspose(256, (3, 3), strides=1, padding='same', activation="relu")(y)

y = Conv2DTranspose(128, (3, 3), strides=2, padding='same', activation="relu")(y)
y = Conv2DTranspose(128, (3, 3), strides=1, padding='same', activation="relu")(y)
y = Conv2DTranspose(128, (3, 3), strides=1, padding='same', activation="relu")(y)
y = Conv2DTranspose(128, (3, 3), strides=1, padding='same', activation="relu")(y)

y = Conv2DTranspose(64, (3, 3), strides=2, padding='same', activation="relu")(y)
y = Conv2DTranspose(64, (3, 3), strides=1, padding='same', activation="relu")(y)
y = Conv2DTranspose(64, (3, 3), strides=1, padding='same', activation="relu")(y)

y = Conv2DTranspose(32, (3, 3), strides=2, padding='same', activation="relu")(y)
y = Conv2DTranspose(32, (3, 3), strides=1, padding='same', activation="relu")(y)
y = Conv2DTranspose(32, (3, 3), strides=1, padding='same', activation="relu")(y)

y = Conv2DTranspose(16, (3, 3), strides=2, padding='same', activation="relu")(y)
y = Conv2DTranspose(16, (3, 3), strides=1, padding='same', activation="relu")(y)
y = Conv2DTranspose(16, (3, 3), strides=1, padding='same', activation="relu")(y)

decoder_output = Conv2DTranspose(3, (3, 3), strides=2, padding='same', activation='sigmoid')(y)

# Decoder Build
decoder = Model(inputs=latent_inputs, outputs=decoder_output, name="decoder")

# %%
class VAE(tf.keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = tf.keras.metrics.Mean(name="total_loss")
        self.reconstruction_loss_tracker = tf.keras.metrics.Mean(
            name="reconstruction_loss"
        )
        self.kl_loss_tracker = tf.keras.metrics.Mean(name="kl_loss")

    @property
    def metrics(self):
        return [
            self.total_loss_tracker,
            self.reconstruction_loss_tracker,
            self.kl_loss_tracker,
        ]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            z_mean, z_log_var, z = self.encoder(data)
            reconstruction = self.decoder(z)
            reconstruction_loss = tf.reduce_mean(
                tf.reduce_sum(
                    tf.keras.losses.binary_crossentropy(data, reconstruction), axis=(1, 2)
                )
            )
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = reconstruction_loss + kl_loss
        grads = tape.gradient(total_loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(reconstruction_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "loss": self.total_loss_tracker.result(),
            "reconstruction_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %% [markdown]
# ## Instantiate Model and Load weights

# %%
vae = VAE(encoder, decoder)

vae.load_weights('/content/drive/MyDrive/Asha FM/raw_data/model/e5100/vae_complex_model_epoch5100')

# %% [markdown]
# ### Predict
#
# FIX ME FIX ME FIX ME FIX ME FIX ME FIX ME FIX ME FIX ME FIX ME FIX ME FIX ME FIX ME
#
# Save latent vectors for ALL images into a numpy array and pickle it. Then it would be easy to load and randomly select vectors.

# %%
# foldername = '../raw_data/zelle'

# def load_images_from_folder(foldername, output_folder):
#     latent_space = []
#     for filename in os.listdir(foldername):
#         with Image.open(os.path.join(foldername,filename)).resize((448,448)) as img:
#             if img is not None:
#                 img = np.asarray(img)
#                 encoded = vae.encoder(img.reshape(-1,448,448,3)/255)
#                 latent_space.append(encoded[2])
#     latent_space = np.concatenate(latent_space, axis=0)
#     np.save('encoded_images.npy', latent_space)
#     return latent_space

# load_images_from_folder(foldername, foldername)

# %%
filename = "encoded_images_npy"

def load_images_from_file(filename):
    latent_space = np.load(filename)
    return latent_space

# %%
N_IMAGES = math.ceil(audio_duration / IMAGE_TIME_GAP + 1)
N_IMAGES
# Out:
# 224

# %%
# encoded_images = load_images_from_file("encoded_images.npy")

# %%
#encoded_images = vae.decoder.predict(encoded_images[0:3 + N_IMAGES])[2]

# %%
encoded_images.shape
# Out:
# (2355, 200)

# %%
random_start_point = np.random.randint(0, encoded_images.shape[0] - N_IMAGES, size=(1))[0]
random_start_point
# Out:
# 1820

# %% [markdown]
# # Create Interpolated Images

# %%
def create_interp_vecs(N_IMAGES, encoded_images, min_factor=0.01, onset_info=onset_info):
    # Empty lists to append new vectors to
    lin_interp_vecs = []
    exp_interp_vecs = []
    
    # We want to interate through the images to be able to interpolate between them
    for i in range(N_IMAGES - 1):
        
        # Get start and stop latent vectors
        start_vec = encoded_images[i]
        end_vec = encoded_images[i + 1]
        
        # get step_vec between image_n and image_n + 1
        step_vec = (end_vec - start_vec) / IMAGE_FRAME_GAP
            
        # We now need to create an image at every frame 
        # Mad props to Charlotte for making this way simpler than I was trying to make it
        for j in range(IMAGE_FRAME_GAP):
            
            current_frame = IMAGE_FRAME_GAP * i + j
            # Check to see if current_frame > total_frames : no point making extra images
            if current_frame > int(onset_info[-1,0]):
                break
            lin_interp_vecs.append(start_vec + (step_vec * j * (onset_info[current_frame, 3] / min_factor + 1)))
            exp_interp_vecs.append(start_vec + (step_vec * j * (onset_info[current_frame, 4] / min_factor + 1)))
            
    return np.array(lin_interp_vecs), np.array(exp_interp_vecs)

# %%
lin_interp_vecs, exp_interp_vecs = create_interp_vecs(N_IMAGES, encoded_images, min_factor=1, onset_info=onset_info)

# %%
lin_interp_vecs.shape, exp_interp_vecs.shape
# Out:
# ((13352, 200), (13352, 200))

# %%
import keras.backend as K
import os

save_path = '/content/drive/MyDrive/Asha FM/raw_data/images/processed_images'


def create_interp_imgs(decoder, exp_interp_vecs, batch_size=1, save_path=save_path):
    # Linear Images
    batch_memory = 500 * 1024 * 1024  # 500 MB

    # num_lin_imgs = len(lin_interp_vecs)
    # lin_interp_imgs = []
    # for i in range(0, num_lin_imgs, batch_size):
    #     batch_vecs = lin_interp_vecs[i:i+batch_size]
    #     batch_imgs = decoder.predict(batch_vecs)
    #     batch_imgs = (batch_imgs * 255).astype('uint8')
    #     lin_interp_imgs.append(batch_imgs)
    #     print(f"Processed {i+batch_size} linear images")
    #     if save_path and i % (500 * 1024 * 1024 // batch_memory) == 0:
    #         if len(lin_interp_imgs) > 0:
    #             np.save(os.path.join(save_path, f"lin_interp_imgs_{i}.npy"), np.concatenate(lin_interp_imgs, axis=0))
    #             lin_interp_imgs = []
    #     K.clear_session()
    # if len(lin_interp_imgs) > 0:
    #     lin_interp_imgs = np.concatenate(lin_interp_imgs, axis=0)
    #     if save_path:
    #         np.save(os.path.join(f"{save_path}/", f"lin_interp_imgs_{num_lin_imgs}.npy"), lin_interp_imgs)
    
    # Exponential Images
    num_exp_imgs = len(exp_interp_vecs)
    exp_interp_imgs = []
    for i in range(0, num_exp_imgs, batch_size):
        batch_vecs = exp_interp_vecs[i:i+batch_size]
        batch_imgs = decoder.predict(batch_vecs)
        batch_imgs = (batch_imgs * 255).astype('uint8')
        exp_interp_imgs.append(batch_imgs)
        print(f"Processed {i+batch_size} exponential images")
        if save_path and i % (500 * 1024 * 1024 // batch_memory) == 0:
            if len(exp_interp_imgs) > 0:
                np.save(os.path.join(save_path, f"exp_interp_imgs_{i}.npy"), np.concatenate(exp_interp_imgs, axis=0))
                exp_interp_imgs = []
        K.clear_session()
    if len(exp_interp_imgs) > 0:
        exp_interp_imgs = np.concatenate(exp_interp_imgs, axis=0)
        if save_path:
            np.save(os.path.join(save_path, f"exp_interp_imgs_{num_exp_imgs}.npy"), exp_interp_imgs)
    
    return exp_interp_imgs

# %%
exp_imgs = create_interp_imgs(vae.decoder, exp_interp_vecs=exp_interp_vecs)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1/1 [==============================] - 0s 285ms/step
# Processed 10853 exponential images
# 1/1 [==============================] - 0s 252ms/step
# Processed 10854 exponential images
# 1/1 [==============================] - 0s 287ms/step
# Processed 10855 exponential images
# 1/1 [==============================] - 0s 263ms/step
# Processed 10856 exponential images
# 1/1 [==============================] - 0s 254ms/step
# Processed 10857 exponential images
# 1/1 [==============================] - 0s 274ms/step
# Processed 10858 exponential images
# 1/1 [==============================] - 0s 254ms/step
# Processed 10859 exponential images
# 1/1 [==============================] - 0s 250ms/step
# Processed 10860 exponential images
# 1/1 [==============================] - 0s 274ms/step
# Processed 10861 exponential images
# 1/1 [==============================] - 0s 265ms/step
# Processed 10862 exponential images
# 1/1 [==============================] - 0s 263ms/step
# Processed 10863 exponential images
# 1/1 [==============================] - 0s 263ms/step
# Processed 10864 exponential images
# 1/1 [==============================] - 0s 257ms/step
# Processed 10865 exponential images
# 1/1 [==============================] - 0s 266ms/step
# Processed 10866 exponential images
# 1/1 [==============================] - 0s 255ms/step
# Processed 10867 exponential images
# 1/1 [==============================] - 0s 247ms/step
# Processed 10868 exponential images
# 1/1 [==============================] - 0s 275ms/step
# Processed 10869 exponential images
# 1/1 [==============================] - 0s 275ms/step
# Processed 10870 exponential images
# 1/1 [==============================] - 0s 257ms/step
# Processed 10871 exponential images
# 1/1 [==============================] - 0s 247ms/step
# Processed 10872 exponential images
# 1/1 [==============================] - 0s 261ms/step
# Processed 10873 exponential images
# 1/1 [==============================] - 0s 265ms/step
# Processed 10874 exponential images
# 1/1 [==============================] - 0s 378ms/step
# Processed 10875 exponential images
# 1/1 [==============================] - 0s 467ms/step
# Processed 10876 exponential images
# 1/1 [==============================] - 0s 457ms/step
# Processed 10877 exponential images
# 1/1 [==============================] - 0s 468ms/step
# Processed 10878 exponential images
# 1/1 [==============================] - 0s 480ms/step
# Processed 10879 exponential images
# 1/1 [==============================] - 0s 465ms/step
# Processed 10880 exponential images
# 1/1 [==============================] - 0s 455ms/step
# Processed 10881 exponential images
# 1/1 [==============================] - 0s 425ms/step
# Processed 10882 exponential images
# 1/1 [==============================] - 0s 280ms/step
# Processed 10883 exponential images
# 1/1 [==============================] - 0s 251ms/step
# Processed 10884 exponential images
# 1/1 [==============================] - 0s 275ms/step
# Processed 10885 exponential images
# 1/1 [==============================] - 0s 253ms/step
# Processed 10886 exponential images
# 1/1 [==============================] - 0s 267ms/step
# Processed 10887 exponential images
# 1/1 [==============================] - 0s 273ms/step
# Processed 10888 exponential images
# 1/1 [==============================] - 0s 245ms/step
# Processed 10889 exponential images
# 1/1 [==============================] - 0s 260ms/step
# Processed 10890 exponential images
# 1/1 [==============================] - 0s 251ms/step
# Processed 10891 exponential images
# 1/1 [==============================] - 0s 250ms/step
# Processed 10892 exponential images
# 1/1 [==============================] - 0s 277ms/step
# Processed 10893 exponential images
# 1/1 [==============================] - 0s 260ms/step
# Processed 10894 exponential images
# 1/1 [==============================] - 0s 259ms/step
# Processed 10895 exponential images
# 1/1 [==============================] - 0s 264ms/step
# Processed 10896 exponential images
# 1/1 [==============================] - 0s 258ms/step
# Processed 10897 exponential images
# 1/1 [==============================] - 0s 265ms/step
# Processed 10898 exponential images
# 1/1 [==============================] - 0s 274ms/step
# Processed 10899 exponential images
# 1/1 [==============================] - 0s 261ms/step
# Processed 10900 exponential images
# 1/1 [==============================] - 0s 272ms/step
# Processed 10901 exponential images
# 1/1 [==============================] - 0s 254ms/step
# Processed 10902 exponential images
# 1/1 [==============================] - 0s 296ms/step
# Processed 10903 exponential images
# 1/1 [==============================] - 0s 268ms/step
# Processed 10904 exponential images
# 1/1 [==============================] - 0s 275ms/step
# Processed 10905 exponential images
# 1/1 [==============================] - 0s 269ms/step
# Processed 10906 exponential images
# 1/1 [==============================] - 0s 250ms/step
# Processed 10907 exponential images
# 1/1 [==============================] - 0s 276ms/step
# Processed 10908 exponential images
# 1/1 [==============================] - 0s 444ms/step
# Processed 10909 exponential images
# 1/1 [==============================] - 0s 460ms/step
# Processed 10910 exponential images
# 1/1 [==============================] - 0s 484ms/step
# Processed 10911 exponential images
# 1/1 [==============================] - 0s 448ms/step
# Processed 10912 exponential images
# 1/1 [==============================] - 0s 461ms/step
# Processed 10913 exponential images
# 1/1 [==============================] - 0s 493ms/step
# Processed 10914 exponential images
# 1/1 [==============================] - 0s 459ms/step
# Processed 10915 exponential images
# 1/1 [==============================] - 0s 453ms/step
# Processed 10916 exponential images
# 1/1 [==============================] - 0s 259ms/step
# Processed 10917 exponential images
# 1/1 [==============================] - 0s 267ms/step
# Processed 10918 exponential images
# 1/1 [==============================] - 0s 278ms/step
# Processed 10919 exponential images
# 1/1 [==============================] - 0s 274ms/step
# Processed 10920 exponential images
# 1/1 [==============================] - 0s 263ms/step
# Processed 10921 exponential images
# 1/1 [==============================] - 0s 244ms/step
# Processed 10922 exponential images
# 1/1 [==============================] - 0s 279ms/step
# Processed 10923 exponential images
# 1/1 [==============================] - 0s 272ms/step
# Processed 10924 exponential images
# 1/1 [==============================] - 0s 275ms/step
# Processed 10925 exponential images
# 1/1 [==============================] - 0s 267ms/step
# Processed 10926 exponential images
# 1/1 [==============================] - 0s 268ms/step
# Processed 10927 exponential images
# 1/1 [==============================] - 0s 259ms/step
# Processed 10928 exponential images
# 1/1 [==============================] - 0s 250ms/step
# Processed 10929 exponential images
# 1/1 [==============================] - 0s 257ms/step
# Processed 10930 exponential images
# 1/1 [==============================] - 0s 251ms/step
# Processed 10931 exponential images
# 1/1 [==============================] - 0s 261ms/step
# Processed 10932 exponential images
# 1/1 [==============================] - 0s 262ms/step
# Processed 10933 exponential images
# 1/1 [==============================] - 0s 260ms/step
# Processed 10934 exponential images
# 1/1 [==============================] - 0s 249ms/step
# Processed 10935 exponential images
# 1/1 [==============================] - 0s 261ms/step
# Processed 10936 exponential images
# 1/1 [==============================] - 0s 251ms/step
# Processed 10937 exponential images
# 1/1 [==============================] - 0s 266ms/step
# Processed 10938 exponential images
# 1/1 [==============================] - 0s 249ms/step
# Processed 10939 exponential images
# 1/1 [==============================] - 0s 280ms/step
# Processed 10940 exponential images
# 1/1 [==============================] - 0s 271ms/step
# Processed 10941 exponential images
# 1/1 [==============================] - 0s 299ms/step
# Processed 10942 exponential images
# 1/1 [==============================] - 0s 448ms/step
# Processed 10943 exponential images
# 1/1 [==============================] - 0s 428ms/step
# Processed 10944 exponential images
# 1/1 [==============================] - 0s 426ms/step
# Processed 10945 exponential images
# 1/1 [==============================] - 0s 442ms/step
# Processed 10946 exponential images
# 1/1 [==============================] - 0s 480ms/step
# Processed 10947 exponential images
# 1/1 [==============================] - 0s 476ms/step
# Processed 10948 exponential images
# 1/1 [==============================] - 0s 444ms/step
# Processed 10949 exponential images
# 1/1 [==============================] - 0s 411ms/step
# Processed 10950 exponential images
# 1/1 [==============================] - 0s 255ms/step
# Processed 10951 exponential images
# 1/1 [==============================] - 0s 252ms/step
# Processed 10952 exponential images
# 1/1 [==============================] - 0s 261ms/step
# Processed 10953 exponential images
# 1/1 [==============================] - 0s 248ms/step
# Processed 10954 exponential images
# 1/1 [==============================] - 0s 261ms/step
# Processed 10955 exponential images
# 1/1 [==============================] - 0s 248ms/step
# Processed 10956 exponential images
# 1/1 [==============================] - 0s 264ms/step
# Processed 10957 exponential images
# 1/1 [==============================] - 0s 275ms/step
# Processed 10958 exponential images
# 1/1 [==============================] - 0s 244ms/step
# Processed 10959 exponential images
# 1/1 [==============================] - 0s 266ms/step
# Processed 10960 exponential images
# 1/1 [==============================] - 0s 246ms/step
# Processed 10961 exponential images
# 1/1 [==============================] - 0s 270ms/step
# Processed 10962 exponential images
# 1/1 [==============================] - 0s 259ms/step
# Processed 10963 exponential images
# 1/1 [==============================] - 0s 397ms/step
# Processed 10964 exponential images
# 1/1 [==============================] - 0s 362ms/step
# Processed 10965 exponential images
# 1/1 [==============================] - 0s 357ms/step
# Processed 10966 exponential images
# 1/1 [==============================] - 0s 369ms/step
# Processed 10967 exponential images
# 1/1 [==============================] - 0s 362ms/step
# Processed 10968 exponential images
# 1/1 [==============================] - 0s 370ms/step
# Processed 10969 exponential images
# 1/1 [==============================] - 0s 363ms/step
# Processed 10970 exponential images
# 1/1 [==============================] - 0s 358ms/step
# Processed 10971 exponential images
# 1/1 [==============================] - 0s 465ms/step
# Processed 10972 exponential images
# 1/1 [==============================] - 1s 562ms/step
# Processed 10973 exponential images
# 1/1 [==============================] - 1s 565ms/step
# Processed 10974 exponential images
# 1/1 [==============================] - 1s 580ms/step
# Processed 10975 exponential images
# 1/1 [==============================] - 1s 560ms/step
# Processed 10976 exponential images
# 1/1 [==============================] - 1s 598ms/step
# Processed 10977 exponential images
# 1/1 [==============================] - 1s 622ms/step
# Processed 10978 exponential images
# 1/1 [==============================] - 0s 372ms/step
# Processed 10979 exponential images
# 1/1 [==============================] - 0s 354ms/step
# Processed 10980 exponential images
# 1/1 [==============================] - 0s 377ms/step
# Processed 10981 exponential images
# 1/1 [==============================] - 0s 391ms/step
# Processed 10982 exponential images
# 1/1 [==============================] - 0s 377ms/step
# Processed 10983 exponential images
# 1/1 [==============================] - 0s 368ms/step
# Processed 10984 exponential images
# 1/1 [==============================] - 0s 378ms/step
# Processed 10985 exponential images
# 1/1 [==============================] - 0s 366ms/step
# Processed 10986 exponential images
# 1/1 [==============================] - 0s 358ms/step
# Processed 10987 exponential images
# 1/1 [==============================] - 0s 393ms/step
# Processed 10988 exponential images
# 1/1 [==============================] - 0s 389ms/step
# Processed 10989 exponential images
# 1/1 [==============================] - 0s 376ms/step
# Processed 10990 exponential images
# 1/1 [==============================] - 0s 348ms/step
# Processed 10991 exponential images
# 1/1 [==============================] - 0s 356ms/step
# Processed 10992 exponential images
# 1/1 [==============================] - 0s 348ms/step
# Processed 10993 exponential images
# 1/1 [==============================] - 0s 371ms/step
# Processed 10994 exponential images
# 1/1 [==============================] - 0s 372ms/step
# Processed 10995 exponential images
# 1/1 [==============================] - 0s 359ms/step
# Processed 10996 exponential images
# 1/1 [==============================] - 0s 379ms/step
# Processed 10997 exponential images
# 1/1 [==============================] - 1s 523ms/step
# Processed 10998 exponential images
# 1/1 [==============================] - 1s 571ms/step
# Processed 10999 exponential images
# 1/1 [==============================] - 1s 547ms/step
# Processed 11000 exponential images
# 1/1 [==============================] - 1s 576ms/step
# Processed 11001 exponential images
# 1/1 [==============================] - 1s 615ms/step
# Processed 11002 exponential images
# 1/1 [==============================] - 1s 562ms/step
# Processed 11003 exponential images
# 1/1 [==============================] - 0s 396ms/step
# Processed 11004 exponential images
# 1/1 [==============================] - 0s 403ms/step
# Processed 11005 exponential images
# 1/1 [==============================] - 0s 366ms/step
# Processed 11006 exponential images
# 1/1 [==============================] - 0s 360ms/step
# Processed 11007 exponential images
# 1/1 [==============================] - 0s 348ms/step
# Processed 11008 exponential images
# 1/1 [==============================] - 0s 351ms/step
# Processed 11009 exponential images
# 1/1 [==============================] - 0s 348ms/step
# Processed 11010 exponential images
# 1/1 [==============================] - 0s 394ms/step
# Processed 11011 exponential images
# 1/1 [==============================] - 0s 397ms/step
# Processed 11012 exponential images
# 1/1 [==============================] - 0s 372ms/step
# Processed 11013 exponential images
# 1/1 [==============================] - 0s 369ms/step
# Processed 11014 exponential images
# 1/1 [==============================] - 0s 355ms/step
# Processed 11015 exponential images
# 1/1 [==============================] - 0s 391ms/step
# Processed 11016 exponential images
# 1/1 [==============================] - 0s 362ms/step
# Processed 11017 exponential images
# 1/1 [==============================] - 0s 385ms/step
# Processed 11018 exponential images
# 1/1 [==============================] - 0s 357ms/step
# Processed 11019 exponential images
# 1/1 [==============================] - 0s 372ms/step
# Processed 11020 exponential images
# 1/1 [==============================] - 0s 391ms/step
# Processed 11021 exponential images
# 1/1 [==============================] - 0s 398ms/step
# Processed 11022 exponential images
# 1/1 [==============================] - 1s 628ms/step
# Processed 11023 exponential images
# 1/1 [==============================] - 1s 593ms/step
# Processed 11024 exponential images
# 1/1 [==============================] - 1s 583ms/step
# Processed 11025 exponential images
# 1/1 [==============================] - 1s 623ms/step
# Processed 11026 exponential images
# 1/1 [==============================] - 1s 634ms/step
# Processed 11027 exponential images
# 1/1 [==============================] - 0s 437ms/step
# Processed 11028 exponential images
# 1/1 [==============================] - 0s 367ms/step
# Processed 11029 exponential images
# 1/1 [==============================] - 0s 413ms/step
# Processed 11030 exponential images
# 1/1 [==============================] - 0s 389ms/step
# Processed 11031 exponential images
# 1/1 [==============================] - 0s 378ms/step
# Processed 11032 exponential images
# 1/1 [==============================] - 0s 396ms/step
# Processed 11033 exponential images
# 1/1 [==============================] - 0s 349ms/step
# Processed 11034 exponential images
# 1/1 [==============================] - 0s 384ms/step
# Processed 11035 exponential images
# 1/1 [==============================] - 0s 355ms/step
# Processed 11036 exponential images
# 1/1 [==============================] - 0s 362ms/step
# Processed 11037 exponential images
# 1/1 [==============================] - 0s 362ms/step
# Processed 11038 exponential images
# 1/1 [==============================] - 0s 381ms/step
# Processed 11039 exponential images
# 1/1 [==============================] - 0s 370ms/step
# Processed 11040 exponential images
# 1/1 [==============================] - 0s 360ms/step
# Processed 11041 exponential images
# 1/1 [==============================] - 0s 354ms/step
# Processed 11042 exponential images
# 1/1 [==============================] - 0s 362ms/step
# Processed 11043 exponential images
# 1/1 [==============================] - 0s 365ms/step
# Processed 11044 exponential images
# 1/1 [==============================] - 0s 348ms/step
# Processed 11045 exponential images
# 1/1 [==============================] - 0s 470ms/step
# Processed 11046 exponential images
# 1/1 [==============================] - 1s 555ms/step
# Processed 11047 exponential images
# 1/1 [==============================] - 1s 559ms/step
# Processed 11048 exponential images
# 1/1 [==============================] - 1s 591ms/step
# Processed 11049 exponential images
# 1/1 [==============================] - 1s 578ms/step
# Processed 11050 exponential images
# 1/1 [==============================] - 1s 555ms/step
# Processed 11051 exponential images
# 1/1 [==============================] - 1s 556ms/step
# Processed 11052 exponential images
# 1/1 [==============================] - 0s 376ms/step
# Processed 11053 exponential images
# 1/1 [==============================] - 0s 396ms/step
# Processed 11054 exponential images
# 1/1 [==============================] - 0s 398ms/step
# Processed 11055 exponential images
# 1/1 [==============================] - 0s 350ms/step
# Processed 11056 exponential images
# 1/1 [==============================] - 0s 381ms/step
# Processed 11057 exponential images
# 1/1 [==============================] - 0s 370ms/step
# Processed 11058 exponential images
# 1/1 [==============================] - 0s 365ms/step
# Processed 11059 exponential images
# 1/1 [==============================] - 0s 408ms/step
# Processed 11060 exponential images
# 1/1 [==============================] - 0s 346ms/step
# Processed 11061 exponential images
# 1/1 [==============================] - 0s 370ms/step
# Processed 11062 exponential images
# 1/1 [==============================] - 0s 396ms/step
# Processed 11063 exponential images
# 1/1 [==============================] - 0s 393ms/step
# Processed 11064 exponential images
# 1/1 [==============================] - 0s 360ms/step
# Processed 11065 exponential images
# 1/1 [==============================] - 0s 372ms/step
# Processed 11066 exponential images
# 1/1 [==============================] - 0s 375ms/step
# Processed 11067 exponential images
# 1/1 [==============================] - 0s 379ms/step
# Processed 11068 exponential images
# 1/1 [==============================] - 0s 366ms/step
# Processed 11069 exponential images
# 1/1 [==============================] - 0s 403ms/step
# Processed 11070 exponential images
# 1/1 [==============================] - 1s 520ms/step
# Processed 11071 exponential images
# 1/1 [==============================] - 1s 656ms/step
# Processed 11072 exponential images
# 1/1 [==============================] - 1s 589ms/step
# Processed 11073 exponential images
# 1/1 [==============================] - 1s 582ms/step
# Processed 11074 exponential images
# 1/1 [==============================] - 1s 615ms/step
# Processed 11075 exponential images
# 1/1 [==============================] - 0s 478ms/step
# Processed 11076 exponential images
# 1/1 [==============================] - 0s 373ms/step
# Processed 11077 exponential images
# 1/1 [==============================] - 0s 365ms/step
# Processed 11078 exponential images
# 1/1 [==============================] - 0s 359ms/step
# Processed 11079 exponential images
# 1/1 [==============================] - 0s 368ms/step
# Processed 11080 exponential images
# 1/1 [==============================] - 0s 377ms/step
# Processed 11081 exponential images
# 1/1 [==============================] - 0s 375ms/step
# Processed 11082 exponential images
# 1/1 [==============================] - 0s 393ms/step
# Processed 11083 exponential images
# 1/1 [==============================] - 0s 407ms/step
# Processed 11084 exponential images
# 1/1 [==============================] - 0s 422ms/step
# Processed 11085 exponential images
# 1/1 [==============================] - 0s 348ms/step
# Processed 11086 exponential images
# 1/1 [==============================] - 0s 348ms/step
# Processed 11087 exponential images
# 1/1 [==============================] - 0s 382ms/step
# Processed 11088 exponential images
# 1/1 [==============================] - 0s 359ms/step
# Processed 11089 exponential images
# 1/1 [==============================] - 0s 369ms/step
# Processed 11090 exponential images
# 1/1 [==============================] - 0s 362ms/step
# Processed 11091 exponential images
# 1/1 [==============================] - 0s 334ms/step
# Processed 11092 exponential images
# 1/1 [==============================] - 0s 396ms/step
# Processed 11093 exponential images
# 1/1 [==============================] - 0s 352ms/step
# Processed 11094 exponential images
# 1/1 [==============================] - 0s 365ms/step
# Processed 11095 exponential images
# 1/1 [==============================] - 1s 608ms/step
# Processed 11096 exponential images
# 1/1 [==============================] - 1s 607ms/step
# Processed 11097 exponential images
# 1/1 [==============================] - 1s 620ms/step
# Processed 11098 exponential images
# 1/1 [==============================] - 1s 557ms/step
# Processed 11099 exponential images
# 1/1 [==============================] - 1s 591ms/step
# Processed 11100 exponential images
# 1/1 [==============================] - 1s 552ms/step
# Processed 11101 exponential images
# 1/1 [==============================] - 0s 381ms/step
# Processed 11102 exponential images
# 1/1 [==============================] - 0s 364ms/step
# Processed 11103 exponential images
# 1/1 [==============================] - 0s 361ms/step
# Processed 11104 exponential images
# 1/1 [==============================] - 0s 354ms/step
# Processed 11105 exponential images
# 1/1 [==============================] - 0s 354ms/step
# Processed 11106 exponential images
# 1/1 [==============================] - 0s 345ms/step
# Processed 11107 exponential images
# 1/1 [==============================] - 0s 354ms/step
# Processed 11108 exponential images
# 1/1 [==============================] - 0s 347ms/step
# Processed 11109 exponential images
# 1/1 [==============================] - 0s 365ms/step
# Processed 11110 exponential images
# 1/1 [==============================] - 0s 349ms/step
# Processed 11111 exponential images
# 1/1 [==============================] - 0s 358ms/step
# Processed 11112 exponential images
# 1/1 [==============================] - 0s 365ms/step
# Processed 11113 exponential images
# 1/1 [==============================] - 0s 363ms/step
# Processed 11114 exponential images
# 1/1 [==============================] - 0s 360ms/step
# Processed 11115 exponential images
# 1/1 [==============================] - 0s 379ms/step
# Processed 11116 exponential images
# 1/1 [==============================] - 0s 339ms/step
# Processed 11117 exponential images
# 1/1 [==============================] - 0s 346ms/step
# Processed 11118 exponential images
# 1/1 [==============================] - 0s 355ms/step
# Processed 11119 exponential images
# 1/1 [==============================] - 0s 375ms/step
# Processed 11120 exponential images
# 1/1 [==============================] - 1s 538ms/step
# Processed 11121 exponential images
# 1/1 [==============================] - 1s 512ms/step
# Processed 11122 exponential images
# 1/1 [==============================] - 1s 586ms/step
# Processed 11123 exponential images
# 1/1 [==============================] - 1s 597ms/step
# Processed 11124 exponential images
# 1/1 [==============================] - 1s 608ms/step
# Processed 11125 exponential images
# 1/1 [==============================] - 1s 561ms/step
# Processed 11126 exponential images
# 1/1 [==============================] - 0s 465ms/step
# Processed 11127 exponential images
# 1/1 [==============================] - 0s 358ms/step
# Processed 11128 exponential images
# 1/1 [==============================] - 0s 360ms/step
# Processed 11129 exponential images
# 1/1 [==============================] - 0s 334ms/step
# Processed 11130 exponential images
# 1/1 [==============================] - 0s 341ms/step
# Processed 11131 exponential images
# 1/1 [==============================] - 0s 343ms/step
# Processed 11132 exponential images
# 1/1 [==============================] - 0s 359ms/step
# Processed 11133 exponential images
# 1/1 [==============================] - 0s 389ms/step
# Processed 11134 exponential images
# 1/1 [==============================] - 0s 360ms/step
# Processed 11135 exponential images
# 1/1 [==============================] - 0s 373ms/step
# Processed 11136 exponential images
# 1/1 [==============================] - 0s 371ms/step
# Processed 11137 exponential images
# 1/1 [==============================] - 0s 350ms/step
# Processed 11138 exponential images
# 1/1 [==============================] - 0s 338ms/step
# Processed 11139 exponential images
# 1/1 [==============================] - 0s 337ms/step
# Processed 11140 exponential images
# 1/1 [==============================] - 0s 330ms/step
# Processed 11141 exponential images
# 1/1 [==============================] - 0s 340ms/step
# Processed 11142 exponential images
# 1/1 [==============================] - 0s 347ms/step
# Processed 11143 exponential images
# 1/1 [==============================] - 0s 348ms/step
# Processed 11144 exponential images
# 1/1 [==============================] - 0s 338ms/step
# Processed 11145 exponential images
# 1/1 [==============================] - 0s 344ms/step
# Processed 11146 exponential images
# 1/1 [==============================] - 0s 338ms/step
# Processed 11147 exponential images
# 1/1 [==============================] - 1s 509ms/step
# Processed 11148 exponential images
# 1/1 [==============================] - 1s 596ms/step
# Processed 11149 exponential images
# 1/1 [==============================] - 1s 590ms/step
# Processed 11150 exponential images
# 1/1 [==============================] - 1s 608ms/step
# Processed 11151 exponential images
# 1/1 [==============================] - 1s 587ms/step
# Processed 11152 exponential images
# 1/1 [==============================] - 1s 566ms/step
# Processed 11153 exponential images
# 1/1 [==============================] - 0s 476ms/step
# Processed 11154 exponential images
# 1/1 [==============================] - 0s 355ms/step
# Processed 11155 exponential images
# 1/1 [==============================] - 0s 325ms/step
# Processed 11156 exponential images
# 1/1 [==============================] - 0s 355ms/step
# Processed 11157 exponential images
# 1/1 [==============================] - 0s 334ms/step
# Processed 11158 exponential images
# 1/1 [==============================] - 0s 345ms/step
# Processed 11159 exponential images
# 1/1 [==============================] - 0s 346ms/step
# Processed 11160 exponential images
# 1/1 [==============================] - 0s 325ms/step
# Processed 11161 exponential images
# 1/1 [==============================] - 0s 336ms/step
# Processed 11162 exponential images
# 1/1 [==============================] - 0s 325ms/step
# Processed 11163 exponential images
# 1/1 [==============================] - 0s 336ms/step
# Processed 11164 exponential images
# 1/1 [==============================] - 0s 336ms/step
# Processed 11165 exponential images
# 1/1 [==============================] - 0s 364ms/step
# Processed 11166 exponential images
# 1/1 [==============================] - 0s 333ms/step
# Processed 11167 exponential images
# 1/1 [==============================] - 0s 331ms/step
# Processed 11168 exponential images
# 1/1 [==============================] - 0s 346ms/step
# Processed 11169 exponential images
# 1/1 [==============================] - 0s 340ms/step
# Processed 11170 exponential images
# 1/1 [==============================] - 0s 337ms/step
# Processed 11171 exponential images
# 1/1 [==============================] - 0s 344ms/step
# Processed 11172 exponential images
# 1/1 [==============================] - 0s 355ms/step
# Processed 11173 exponential images
# 1/1 [==============================] - 0s 347ms/step
# Processed 11174 exponential images
# 1/1 [==============================] - 1s 584ms/step
# Processed 11175 exponential images
# 1/1 [==============================] - 1s 637ms/step
# Processed 11176 exponential images
# 1/1 [==============================] - 1s 627ms/step
# Processed 11177 exponential images
# 1/1 [==============================] - 1s 604ms/step
# Processed 11178 exponential images
# 1/1 [==============================] - 1s 700ms/step
# Processed 11179 exponential images
# 1/1 [==============================] - 1s 717ms/step
# Processed 11180 exponential images
# 1/1 [==============================] - 1s 681ms/step
# Processed 11181 exponential images
# 1/1 [==============================] - 1s 582ms/step
# Processed 11182 exponential images
# 1/1 [==============================] - 1s 604ms/step
# Processed 11183 exponential images
# 1/1 [==============================] - 1s 531ms/step
# Processed 11184 exponential images
# 1/1 [==============================] - 0s 345ms/step
# Processed 11185 exponential images
# 1/1 [==============================] - 0s 343ms/step
# Processed 11186 exponential images
# 1/1 [==============================] - 0s 328ms/step
# Processed 11187 exponential images
# 1/1 [==============================] - 0s 327ms/step
# Processed 11188 exponential images
# 1/1 [==============================] - 0s 328ms/step
# Processed 11189 exponential images
# 1/1 [==============================] - 0s 359ms/step
# Processed 11190 exponential images
# 1/1 [==============================] - 0s 322ms/step
# Processed 11191 exponential images
# 1/1 [==============================] - 0s 341ms/step
# Processed 11192 exponential images
# 1/1 [==============================] - 0s 334ms/step
# Processed 11193 exponential images
# 1/1 [==============================] - 0s 352ms/step
# Processed 11194 exponential images
# 1/1 [==============================] - 0s 347ms/step
# Processed 11195 exponential images
# 1/1 [==============================] - 0s 323ms/step
# Processed 11196 exponential images
# 1/1 [==============================] - 0s 339ms/step
# Processed 11197 exponential images
# 1/1 [==============================] - 0s 326ms/step
# Processed 11198 exponential images
# 1/1 [==============================] - 0s 346ms/step
# Processed 11199 exponential images
# 1/1 [==============================] - 0s 371ms/step
# Processed 11200 exponential images
# 1/1 [==============================] - 0s 333ms/step
# Processed 11201 exponential images
# 1/1 [==============================] - 0s 351ms/step
# Processed 11202 exponential images
# 1/1 [==============================] - 0s 329ms/step
# Processed 11203 exponential images
# 1/1 [==============================] - 0s 346ms/step
# Processed 11204 exponential images
# 1/1 [==============================] - 0s 441ms/step
# Processed 11205 exponential images
# 1/1 [==============================] - 1s 533ms/step
# Processed 11206 exponential images
# 1/1 [==============================] - 1s 564ms/step
# Processed 11207 exponential images
# 1/1 [==============================] - 1s 579ms/step
# Processed 11208 exponential images
# 1/1 [==============================] - 1s 533ms/step
# Processed 11209 exponential images
# 1/1 [==============================] - 1s 604ms/step
# Processed 11210 exponential images
# 1/1 [==============================] - 1s 523ms/step
# Processed 11211 exponential images
# 1/1 [==============================] - 0s 344ms/step
# Processed 11212 exponential images
# 1/1 [==============================] - 0s 314ms/step
# Processed 11213 exponential images
# 1/1 [==============================] - 0s 345ms/step
# Processed 11214 exponential images
# 1/1 [==============================] - 0s 324ms/step
# Processed 11215 exponential images
# 1/1 [==============================] - 0s 338ms/step
# Processed 11216 exponential images
# 1/1 [==============================] - 0s 338ms/step
# Processed 11217 exponential images
# 1/1 [==============================] - 0s 335ms/step
# Processed 11218 exponential images
# 1/1 [==============================] - 0s 322ms/step
# Processed 11219 exponential images
# 1/1 [==============================] - 0s 330ms/step
# Processed 11220 exponential images
# 1/1 [==============================] - 0s 301ms/step
# Processed 11221 exponential images
# 1/1 [==============================] - 0s 339ms/step
# Processed 11222 exponential images
# 1/1 [==============================] - 0s 348ms/step
# Processed 11223 exponential images
# 1/1 [==============================] - 0s 343ms/step
# Processed 11224 exponential images
# 1/1 [==============================] - 0s 361ms/step
# Processed 11225 exponential images
# 1/1 [==============================] - 0s 317ms/step
# Processed 11226 exponential images
# 1/1 [==============================] - 0s 333ms/step
# Processed 11227 exponential images
# 1/1 [==============================] - 0s 323ms/step
# Processed 11228 exponential images
# 1/1 [==============================] - 0s 336ms/step
# Processed 11229 exponential images
# 1/1 [==============================] - 0s 340ms/step
# Processed 11230 exponential images
# 1/1 [==============================] - 0s 336ms/step
# Processed 11231 exponential images
# 1/1 [==============================] - 0s 307ms/step
# Processed 11232 exponential images
# 1/1 [==============================] - 1s 554ms/step
# Processed 11233 exponential images
# 1/1 [==============================] - 1s 535ms/step
# Processed 11234 exponential images
# 1/1 [==============================] - 1s 567ms/step
# Processed 11235 exponential images
# 1/1 [==============================] - 1s 541ms/step
# Processed 11236 exponential images
# 1/1 [==============================] - 1s 532ms/step
# Processed 11237 exponential images
# 1/1 [==============================] - 1s 511ms/step
# Processed 11238 exponential images
# 1/1 [==============================] - 0s 490ms/step
# Processed 11239 exponential images
# 1/1 [==============================] - 0s 331ms/step
# Processed 11240 exponential images
# 1/1 [==============================] - 0s 319ms/step
# Processed 11241 exponential images
# 1/1 [==============================] - 0s 328ms/step
# Processed 11242 exponential images
# 1/1 [==============================] - 0s 316ms/step
# Processed 11243 exponential images
# 1/1 [==============================] - 0s 341ms/step
# Processed 11244 exponential images
# 1/1 [==============================] - 0s 356ms/step
# Processed 11245 exponential images
# 1/1 [==============================] - 0s 337ms/step
# Processed 11246 exponential images
# 1/1 [==============================] - 0s 347ms/step
# Processed 11247 exponential images
# 1/1 [==============================] - 0s 341ms/step
# Processed 11248 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 11249 exponential images
# 1/1 [==============================] - 0s 317ms/step
# Processed 11250 exponential images
# 1/1 [==============================] - 0s 313ms/step
# Processed 11251 exponential images
# 1/1 [==============================] - 0s 305ms/step
# Processed 11252 exponential images
# 1/1 [==============================] - 0s 328ms/step
# Processed 11253 exponential images
# 1/1 [==============================] - 0s 321ms/step
# Processed 11254 exponential images
# 1/1 [==============================] - 0s 319ms/step
# Processed 11255 exponential images
# 1/1 [==============================] - 0s 324ms/step
# Processed 11256 exponential images
# 1/1 [==============================] - 0s 312ms/step
# Processed 11257 exponential images
# 1/1 [==============================] - 0s 334ms/step
# Processed 11258 exponential images
# 1/1 [==============================] - 0s 313ms/step
# Processed 11259 exponential images
# 1/1 [==============================] - 1s 533ms/step
# Processed 11260 exponential images
# 1/1 [==============================] - 1s 605ms/step
# Processed 11261 exponential images
# 1/1 [==============================] - 1s 548ms/step
# Processed 11262 exponential images
# 1/1 [==============================] - 1s 554ms/step
# Processed 11263 exponential images
# 1/1 [==============================] - 1s 510ms/step
# Processed 11264 exponential images
# 1/1 [==============================] - 1s 507ms/step
# Processed 11265 exponential images
# 1/1 [==============================] - 0s 392ms/step
# Processed 11266 exponential images
# 1/1 [==============================] - 0s 317ms/step
# Processed 11267 exponential images
# 1/1 [==============================] - 0s 340ms/step
# Processed 11268 exponential images
# 1/1 [==============================] - 0s 341ms/step
# Processed 11269 exponential images
# 1/1 [==============================] - 0s 329ms/step
# Processed 11270 exponential images
# 1/1 [==============================] - 0s 342ms/step
# Processed 11271 exponential images
# 1/1 [==============================] - 0s 322ms/step
# Processed 11272 exponential images
# 1/1 [==============================] - 0s 321ms/step
# Processed 11273 exponential images
# 1/1 [==============================] - 0s 334ms/step
# Processed 11274 exponential images
# 1/1 [==============================] - 0s 346ms/step
# Processed 11275 exponential images
# 1/1 [==============================] - 0s 337ms/step
# Processed 11276 exponential images
# 1/1 [==============================] - 0s 342ms/step
# Processed 11277 exponential images
# 1/1 [==============================] - 0s 331ms/step
# Processed 11278 exponential images
# 1/1 [==============================] - 0s 324ms/step
# Processed 11279 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 11280 exponential images
# 1/1 [==============================] - 0s 317ms/step
# Processed 11281 exponential images
# 1/1 [==============================] - 0s 358ms/step
# Processed 11282 exponential images
# 1/1 [==============================] - 0s 315ms/step
# Processed 11283 exponential images
# 1/1 [==============================] - 0s 340ms/step
# Processed 11284 exponential images
# 1/1 [==============================] - 0s 335ms/step
# Processed 11285 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 11286 exponential images
# 1/1 [==============================] - 1s 557ms/step
# Processed 11287 exponential images
# 1/1 [==============================] - 1s 568ms/step
# Processed 11288 exponential images
# 1/1 [==============================] - 1s 521ms/step
# Processed 11289 exponential images
# 1/1 [==============================] - 1s 569ms/step
# Processed 11290 exponential images
# 1/1 [==============================] - 1s 565ms/step
# Processed 11291 exponential images
# 1/1 [==============================] - 1s 552ms/step
# Processed 11292 exponential images
# 1/1 [==============================] - 0s 444ms/step
# Processed 11293 exponential images
# 1/1 [==============================] - 0s 353ms/step
# Processed 11294 exponential images
# 1/1 [==============================] - 0s 318ms/step
# Processed 11295 exponential images
# 1/1 [==============================] - 0s 322ms/step
# Processed 11296 exponential images
# 1/1 [==============================] - 0s 312ms/step
# Processed 11297 exponential images
# 1/1 [==============================] - 0s 325ms/step
# Processed 11298 exponential images
# 1/1 [==============================] - 0s 317ms/step
# Processed 11299 exponential images
# 1/1 [==============================] - 0s 335ms/step
# Processed 11300 exponential images
# 1/1 [==============================] - 0s 339ms/step
# Processed 11301 exponential images
# 1/1 [==============================] - 0s 323ms/step
# Processed 11302 exponential images
# 1/1 [==============================] - 0s 307ms/step
# Processed 11303 exponential images
# 1/1 [==============================] - 0s 315ms/step
# Processed 11304 exponential images
# 1/1 [==============================] - 0s 322ms/step
# Processed 11305 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 11306 exponential images
# 1/1 [==============================] - 0s 326ms/step
# Processed 11307 exponential images
# 1/1 [==============================] - 0s 305ms/step
# Processed 11308 exponential images
# 1/1 [==============================] - 0s 332ms/step
# Processed 11309 exponential images
# 1/1 [==============================] - 0s 331ms/step
# Processed 11310 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 11311 exponential images
# 1/1 [==============================] - 0s 332ms/step
# Processed 11312 exponential images
# 1/1 [==============================] - 0s 337ms/step
# Processed 11313 exponential images
# 1/1 [==============================] - 0s 496ms/step
# Processed 11314 exponential images
# 1/1 [==============================] - 1s 525ms/step
# Processed 11315 exponential images
# 1/1 [==============================] - 1s 526ms/step
# Processed 11316 exponential images
# 1/1 [==============================] - 1s 551ms/step
# Processed 11317 exponential images
# 1/1 [==============================] - 1s 544ms/step
# Processed 11318 exponential images
# 1/1 [==============================] - 1s 503ms/step
# Processed 11319 exponential images
# 1/1 [==============================] - 1s 505ms/step
# Processed 11320 exponential images
# 1/1 [==============================] - 0s 324ms/step
# Processed 11321 exponential images
# 1/1 [==============================] - 0s 322ms/step
# Processed 11322 exponential images
# 1/1 [==============================] - 0s 313ms/step
# Processed 11323 exponential images
# 1/1 [==============================] - 0s 328ms/step
# Processed 11324 exponential images
# 1/1 [==============================] - 0s 352ms/step
# Processed 11325 exponential images
# 1/1 [==============================] - 0s 329ms/step
# Processed 11326 exponential images
# 1/1 [==============================] - 0s 367ms/step
# Processed 11327 exponential images
# 1/1 [==============================] - 0s 311ms/step
# Processed 11328 exponential images
# 1/1 [==============================] - 0s 317ms/step
# Processed 11329 exponential images
# 1/1 [==============================] - 0s 321ms/step
# Processed 11330 exponential images
# 1/1 [==============================] - 0s 310ms/step
# Processed 11331 exponential images
# 1/1 [==============================] - 0s 334ms/step
# Processed 11332 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 11333 exponential images
# 1/1 [==============================] - 0s 324ms/step
# Processed 11334 exponential images
# 1/1 [==============================] - 0s 307ms/step
# Processed 11335 exponential images
# 1/1 [==============================] - 0s 318ms/step
# Processed 11336 exponential images
# 1/1 [==============================] - 0s 309ms/step
# Processed 11337 exponential images
# 1/1 [==============================] - 0s 313ms/step
# Processed 11338 exponential images
# 1/1 [==============================] - 0s 304ms/step
# Processed 11339 exponential images
# 1/1 [==============================] - 0s 307ms/step
# Processed 11340 exponential images
# 1/1 [==============================] - 0s 310ms/step
# Processed 11341 exponential images
# 1/1 [==============================] - 0s 321ms/step
# Processed 11342 exponential images
# 1/1 [==============================] - 1s 544ms/step
# Processed 11343 exponential images
# 1/1 [==============================] - 1s 519ms/step
# Processed 11344 exponential images
# 1/1 [==============================] - 1s 524ms/step
# Processed 11345 exponential images
# 1/1 [==============================] - 1s 528ms/step
# Processed 11346 exponential images
# 1/1 [==============================] - 1s 525ms/step
# Processed 11347 exponential images
# 1/1 [==============================] - 0s 478ms/step
# Processed 11348 exponential images
# 1/1 [==============================] - 0s 487ms/step
# Processed 11349 exponential images
# 1/1 [==============================] - 0s 330ms/step
# Processed 11350 exponential images
# 1/1 [==============================] - 0s 326ms/step
# Processed 11351 exponential images
# 1/1 [==============================] - 0s 318ms/step
# Processed 11352 exponential images
# 1/1 [==============================] - 0s 303ms/step
# Processed 11353 exponential images
# 1/1 [==============================] - 0s 299ms/step
# Processed 11354 exponential images
# 1/1 [==============================] - 0s 329ms/step
# Processed 11355 exponential images
# 1/1 [==============================] - 0s 318ms/step
# Processed 11356 exponential images
# 1/1 [==============================] - 0s 334ms/step
# Processed 11357 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 11358 exponential images
# 1/1 [==============================] - 0s 296ms/step
# Processed 11359 exponential images
# 1/1 [==============================] - 0s 309ms/step
# Processed 11360 exponential images
# 1/1 [==============================] - 0s 298ms/step
# Processed 11361 exponential images
# 1/1 [==============================] - 0s 321ms/step
# Processed 11362 exponential images
# 1/1 [==============================] - 0s 326ms/step
# Processed 11363 exponential images
# 1/1 [==============================] - 0s 312ms/step
# Processed 11364 exponential images
# 1/1 [==============================] - 0s 330ms/step
# Processed 11365 exponential images
# 1/1 [==============================] - 0s 325ms/step
# Processed 11366 exponential images
# 1/1 [==============================] - 0s 304ms/step
# Processed 11367 exponential images
# 1/1 [==============================] - 0s 312ms/step
# Processed 11368 exponential images
# 1/1 [==============================] - 0s 302ms/step
# Processed 11369 exponential images
# 1/1 [==============================] - 0s 305ms/step
# Processed 11370 exponential images
# 1/1 [==============================] - 1s 517ms/step
# Processed 11371 exponential images
# 1/1 [==============================] - 1s 518ms/step
# Processed 11372 exponential images
# 1/1 [==============================] - 1s 522ms/step
# Processed 11373 exponential images
# 1/1 [==============================] - 1s 551ms/step
# Processed 11374 exponential images
# 1/1 [==============================] - 1s 529ms/step
# Processed 11375 exponential images
# 1/1 [==============================] - 1s 504ms/step
# Processed 11376 exponential images
# 1/1 [==============================] - 1s 570ms/step
# Processed 11377 exponential images
# 1/1 [==============================] - 0s 392ms/step
# Processed 11378 exponential images
# 1/1 [==============================] - 1s 525ms/step
# Processed 11379 exponential images
# 1/1 [==============================] - 0s 299ms/step
# Processed 11380 exponential images
# 1/1 [==============================] - 0s 323ms/step
# Processed 11381 exponential images
# 1/1 [==============================] - 0s 301ms/step
# Processed 11382 exponential images
# 1/1 [==============================] - 0s 319ms/step
# Processed 11383 exponential images
# 1/1 [==============================] - 0s 312ms/step
# Processed 11384 exponential images
# 1/1 [==============================] - 0s 317ms/step
# Processed 11385 exponential images
# 1/1 [==============================] - 0s 310ms/step
# Processed 11386 exponential images
# 1/1 [==============================] - 0s 304ms/step
# Processed 11387 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 11388 exponential images
# 1/1 [==============================] - 0s 316ms/step
# Processed 11389 exponential images
# 1/1 [==============================] - 0s 321ms/step
# Processed 11390 exponential images
# 1/1 [==============================] - 0s 350ms/step
# Processed 11391 exponential images
# 1/1 [==============================] - 0s 315ms/step
# Processed 11392 exponential images
# 1/1 [==============================] - 0s 328ms/step
# Processed 11393 exponential images
# 1/1 [==============================] - 0s 306ms/step
# Processed 11394 exponential images
# 1/1 [==============================] - 0s 305ms/step
# Processed 11395 exponential images
# 1/1 [==============================] - 0s 306ms/step
# Processed 11396 exponential images
# 1/1 [==============================] - 0s 308ms/step
# ...
# Processed 13171 exponential images
# 1/1 [==============================] - 0s 425ms/step
# Processed 13172 exponential images
# 1/1 [==============================] - 1s 534ms/step
# Processed 13173 exponential images
# 1/1 [==============================] - 1s 588ms/step
# Processed 13174 exponential images
# 1/1 [==============================] - 1s 551ms/step
# Processed 13175 exponential images
# 1/1 [==============================] - 1s 518ms/step
# Processed 13176 exponential images
# 1/1 [==============================] - 1s 571ms/step
# Processed 13177 exponential images
# 1/1 [==============================] - 0s 406ms/step
# Processed 13178 exponential images
# 1/1 [==============================] - 0s 324ms/step
# Processed 13179 exponential images
# 1/1 [==============================] - 0s 325ms/step
# Processed 13180 exponential images
# 1/1 [==============================] - 0s 307ms/step
# Processed 13181 exponential images
# 1/1 [==============================] - 0s 328ms/step
# Processed 13182 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 13183 exponential images
# 1/1 [==============================] - 0s 321ms/step
# Processed 13184 exponential images
# 1/1 [==============================] - 0s 321ms/step
# Processed 13185 exponential images
# 1/1 [==============================] - 0s 338ms/step
# Processed 13186 exponential images
# 1/1 [==============================] - 0s 301ms/step
# Processed 13187 exponential images
# 1/1 [==============================] - 0s 304ms/step
# Processed 13188 exponential images
# 1/1 [==============================] - 0s 312ms/step
# Processed 13189 exponential images
# 1/1 [==============================] - 0s 299ms/step
# Processed 13190 exponential images
# 1/1 [==============================] - 0s 321ms/step
# Processed 13191 exponential images
# 1/1 [==============================] - 0s 304ms/step
# Processed 13192 exponential images
# 1/1 [==============================] - 0s 327ms/step
# Processed 13193 exponential images
# 1/1 [==============================] - 0s 288ms/step
# Processed 13194 exponential images
# 1/1 [==============================] - 0s 336ms/step
# Processed 13195 exponential images
# 1/1 [==============================] - 0s 327ms/step
# Processed 13196 exponential images
# 1/1 [==============================] - 0s 311ms/step
# Processed 13197 exponential images
# 1/1 [==============================] - 0s 310ms/step
# Processed 13198 exponential images
# 1/1 [==============================] - 0s 296ms/step
# Processed 13199 exponential images
# 1/1 [==============================] - 0s 344ms/step
# Processed 13200 exponential images
# 1/1 [==============================] - 1s 584ms/step
# Processed 13201 exponential images
# 1/1 [==============================] - 1s 528ms/step
# Processed 13202 exponential images
# 1/1 [==============================] - 1s 538ms/step
# Processed 13203 exponential images
# 1/1 [==============================] - 1s 522ms/step
# Processed 13204 exponential images
# 1/1 [==============================] - 0s 499ms/step
# Processed 13205 exponential images
# 1/1 [==============================] - 1s 546ms/step
# Processed 13206 exponential images
# 1/1 [==============================] - 0s 475ms/step
# Processed 13207 exponential images
# 1/1 [==============================] - 0s 309ms/step
# Processed 13208 exponential images
# 1/1 [==============================] - 0s 304ms/step
# Processed 13209 exponential images
# 1/1 [==============================] - 0s 295ms/step
# Processed 13210 exponential images
# 1/1 [==============================] - 0s 301ms/step
# Processed 13211 exponential images
# 1/1 [==============================] - 0s 308ms/step
# Processed 13212 exponential images
# 1/1 [==============================] - 0s 332ms/step
# Processed 13213 exponential images
# 1/1 [==============================] - 0s 339ms/step
# Processed 13214 exponential images
# 1/1 [==============================] - 0s 338ms/step
# Processed 13215 exponential images
# 1/1 [==============================] - 0s 313ms/step
# Processed 13216 exponential images
# 1/1 [==============================] - 0s 311ms/step
# Processed 13217 exponential images
# 1/1 [==============================] - 0s 301ms/step
# Processed 13218 exponential images
# 1/1 [==============================] - 0s 310ms/step
# Processed 13219 exponential images
# 1/1 [==============================] - 0s 344ms/step
# Processed 13220 exponential images
# 1/1 [==============================] - 0s 348ms/step
# Processed 13221 exponential images
# 1/1 [==============================] - 0s 307ms/step
# Processed 13222 exponential images
# 1/1 [==============================] - 0s 322ms/step
# Processed 13223 exponential images
# 1/1 [==============================] - 0s 308ms/step
# Processed 13224 exponential images
# 1/1 [==============================] - 0s 326ms/step
# Processed 13225 exponential images
# 1/1 [==============================] - 0s 294ms/step
# Processed 13226 exponential images
# 1/1 [==============================] - 0s 318ms/step
# Processed 13227 exponential images
# 1/1 [==============================] - 0s 342ms/step
# Processed 13228 exponential images
# 1/1 [==============================] - 0s 339ms/step
# Processed 13229 exponential images
# 1/1 [==============================] - 0s 368ms/step
# Processed 13230 exponential images
# 1/1 [==============================] - 1s 585ms/step
# Processed 13231 exponential images
# 1/1 [==============================] - 0s 500ms/step
# Processed 13232 exponential images
# 1/1 [==============================] - 1s 538ms/step
# Processed 13233 exponential images
# 1/1 [==============================] - 1s 553ms/step
# Processed 13234 exponential images
# 1/1 [==============================] - 1s 503ms/step
# Processed 13235 exponential images
# 1/1 [==============================] - 0s 472ms/step
# Processed 13236 exponential images
# 1/1 [==============================] - 0s 327ms/step
# Processed 13237 exponential images
# 1/1 [==============================] - 0s 318ms/step
# Processed 13238 exponential images
# 1/1 [==============================] - 0s 326ms/step
# Processed 13239 exponential images
# 1/1 [==============================] - 0s 315ms/step
# Processed 13240 exponential images
# 1/1 [==============================] - 0s 307ms/step
# Processed 13241 exponential images
# 1/1 [==============================] - 0s 316ms/step
# Processed 13242 exponential images
# 1/1 [==============================] - 0s 325ms/step
# Processed 13243 exponential images
# 1/1 [==============================] - 0s 325ms/step
# Processed 13244 exponential images
# 1/1 [==============================] - 0s 309ms/step
# Processed 13245 exponential images
# 1/1 [==============================] - 0s 304ms/step
# Processed 13246 exponential images
# 1/1 [==============================] - 0s 295ms/step
# Processed 13247 exponential images
# 1/1 [==============================] - 0s 291ms/step
# Processed 13248 exponential images
# 1/1 [==============================] - 0s 300ms/step
# Processed 13249 exponential images
# 1/1 [==============================] - 0s 287ms/step
# Processed 13250 exponential images
# 1/1 [==============================] - 0s 290ms/step
# Processed 13251 exponential images
# 1/1 [==============================] - 0s 310ms/step
# Processed 13252 exponential images
# 1/1 [==============================] - 0s 304ms/step
# Processed 13253 exponential images
# 1/1 [==============================] - 0s 307ms/step
# Processed 13254 exponential images
# 1/1 [==============================] - 0s 298ms/step
# Processed 13255 exponential images
# 1/1 [==============================] - 0s 286ms/step
# Processed 13256 exponential images
# 1/1 [==============================] - 0s 313ms/step
# Processed 13257 exponential images
# 1/1 [==============================] - 0s 315ms/step
# Processed 13258 exponential images
# 1/1 [==============================] - 1s 571ms/step
# Processed 13259 exponential images
# 1/1 [==============================] - 1s 554ms/step
# Processed 13260 exponential images
# 1/1 [==============================] - 0s 459ms/step
# Processed 13261 exponential images
# 1/1 [==============================] - 1s 531ms/step
# Processed 13262 exponential images
# 1/1 [==============================] - 1s 506ms/step
# Processed 13263 exponential images
# 1/1 [==============================] - 1s 516ms/step
# Processed 13264 exponential images
# 1/1 [==============================] - 0s 495ms/step
# Processed 13265 exponential images
# 1/1 [==============================] - 0s 351ms/step
# Processed 13266 exponential images
# 1/1 [==============================] - 0s 295ms/step
# Processed 13267 exponential images
# 1/1 [==============================] - 0s 310ms/step
# Processed 13268 exponential images
# 1/1 [==============================] - 0s 328ms/step
# Processed 13269 exponential images
# 1/1 [==============================] - 0s 288ms/step
# Processed 13270 exponential images
# 1/1 [==============================] - 0s 292ms/step
# Processed 13271 exponential images
# 1/1 [==============================] - 0s 309ms/step
# Processed 13272 exponential images
# 1/1 [==============================] - 0s 297ms/step
# Processed 13273 exponential images
# 1/1 [==============================] - 0s 306ms/step
# Processed 13274 exponential images
# 1/1 [==============================] - 0s 298ms/step
# Processed 13275 exponential images
# 1/1 [==============================] - 0s 305ms/step
# Processed 13276 exponential images
# 1/1 [==============================] - 0s 301ms/step
# Processed 13277 exponential images
# 1/1 [==============================] - 0s 346ms/step
# Processed 13278 exponential images
# 1/1 [==============================] - 0s 309ms/step
# Processed 13279 exponential images
# 1/1 [==============================] - 0s 287ms/step
# Processed 13280 exponential images
# 1/1 [==============================] - 0s 308ms/step
# Processed 13281 exponential images
# 1/1 [==============================] - 0s 301ms/step
# Processed 13282 exponential images
# 1/1 [==============================] - 0s 299ms/step
# Processed 13283 exponential images
# 1/1 [==============================] - 0s 296ms/step
# Processed 13284 exponential images
# 1/1 [==============================] - 0s 315ms/step
# Processed 13285 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 13286 exponential images
# 1/1 [==============================] - 0s 305ms/step
# Processed 13287 exponential images
# 1/1 [==============================] - 0s 336ms/step
# Processed 13288 exponential images
# 1/1 [==============================] - 0s 491ms/step
# Processed 13289 exponential images
# 1/1 [==============================] - 1s 514ms/step
# Processed 13290 exponential images
# 1/1 [==============================] - 1s 539ms/step
# Processed 13291 exponential images
# 1/1 [==============================] - 0s 488ms/step
# Processed 13292 exponential images
# 1/1 [==============================] - 0s 496ms/step
# Processed 13293 exponential images
# 1/1 [==============================] - 1s 530ms/step
# Processed 13294 exponential images
# 1/1 [==============================] - 0s 410ms/step
# Processed 13295 exponential images
# 1/1 [==============================] - 0s 312ms/step
# Processed 13296 exponential images
# 1/1 [==============================] - 0s 310ms/step
# Processed 13297 exponential images
# 1/1 [==============================] - 0s 313ms/step
# Processed 13298 exponential images
# 1/1 [==============================] - 0s 312ms/step
# Processed 13299 exponential images
# 1/1 [==============================] - 0s 326ms/step
# Processed 13300 exponential images
# 1/1 [==============================] - 0s 293ms/step
# Processed 13301 exponential images
# 1/1 [==============================] - 0s 294ms/step
# Processed 13302 exponential images
# 1/1 [==============================] - 0s 304ms/step
# Processed 13303 exponential images
# 1/1 [==============================] - 0s 299ms/step
# Processed 13304 exponential images
# 1/1 [==============================] - 0s 288ms/step
# Processed 13305 exponential images
# 1/1 [==============================] - 0s 320ms/step
# Processed 13306 exponential images
# 1/1 [==============================] - 0s 297ms/step
# Processed 13307 exponential images
# 1/1 [==============================] - 0s 301ms/step
# Processed 13308 exponential images
# 1/1 [==============================] - 0s 284ms/step
# Processed 13309 exponential images
# 1/1 [==============================] - 0s 296ms/step
# Processed 13310 exponential images
# 1/1 [==============================] - 0s 277ms/step
# Processed 13311 exponential images
# 1/1 [==============================] - 0s 293ms/step
# Processed 13312 exponential images
# 1/1 [==============================] - 0s 281ms/step
# Processed 13313 exponential images
# 1/1 [==============================] - 0s 294ms/step
# Processed 13314 exponential images
# 1/1 [==============================] - 0s 289ms/step
# Processed 13315 exponential images
# 1/1 [==============================] - 0s 310ms/step
# Processed 13316 exponential images
# 1/1 [==============================] - 0s 303ms/step
# Processed 13317 exponential images
# 1/1 [==============================] - 0s 384ms/step
# Processed 13318 exponential images
# 1/1 [==============================] - 1s 517ms/step
# Processed 13319 exponential images
# 1/1 [==============================] - 0s 492ms/step
# Processed 13320 exponential images
# 1/1 [==============================] - 1s 511ms/step
# Processed 13321 exponential images
# 1/1 [==============================] - 1s 513ms/step
# Processed 13322 exponential images
# 1/1 [==============================] - 1s 547ms/step
# Processed 13323 exponential images
# 1/1 [==============================] - 1s 523ms/step
# Processed 13324 exponential images
# 1/1 [==============================] - 0s 379ms/step
# Processed 13325 exponential images
# 1/1 [==============================] - 0s 305ms/step
# Processed 13326 exponential images
# 1/1 [==============================] - 0s 313ms/step
# Processed 13327 exponential images
# 1/1 [==============================] - 0s 280ms/step
# Processed 13328 exponential images
# 1/1 [==============================] - 0s 305ms/step
# Processed 13329 exponential images
# 1/1 [==============================] - 0s 292ms/step
# Processed 13330 exponential images
# 1/1 [==============================] - 0s 306ms/step
# Processed 13331 exponential images
# 1/1 [==============================] - 0s 301ms/step
# Processed 13332 exponential images
# 1/1 [==============================] - 0s 302ms/step
# Processed 13333 exponential images
# 1/1 [==============================] - 0s 302ms/step
# Processed 13334 exponential images
# 1/1 [==============================] - 0s 308ms/step
# Processed 13335 exponential images
# 1/1 [==============================] - 0s 298ms/step
# Processed 13336 exponential images
# 1/1 [==============================] - 0s 290ms/step
# Processed 13337 exponential images
# 1/1 [==============================] - 0s 302ms/step
# Processed 13338 exponential images
# 1/1 [==============================] - 0s 312ms/step
# Processed 13339 exponential images
# 1/1 [==============================] - 0s 298ms/step
# Processed 13340 exponential images
# 1/1 [==============================] - 0s 294ms/step
# Processed 13341 exponential images
# 1/1 [==============================] - 0s 307ms/step
# Processed 13342 exponential images
# 1/1 [==============================] - 0s 281ms/step
# Processed 13343 exponential images
# 1/1 [==============================] - 0s 297ms/step
# Processed 13344 exponential images
# 1/1 [==============================] - 0s 294ms/step
# Processed 13345 exponential images
# 1/1 [==============================] - 0s 313ms/step
# Processed 13346 exponential images
# 1/1 [==============================] - 0s 302ms/step
# Processed 13347 exponential images
# 1/1 [==============================] - 0s 416ms/step
# Processed 13348 exponential images
# 1/1 [==============================] - 0s 484ms/step
# Processed 13349 exponential images
# 1/1 [==============================] - 0s 484ms/step
# Processed 13350 exponential images
# 1/1 [==============================] - 0s 475ms/step
# Processed 13351 exponential images
# 1/1 [==============================] - 0s 498ms/step
# Processed 13352 exponential images

# %%
# def concatenate_lin_interp_imgs(save_path, num_lin_imgs):
#     lin_interp_imgs = []
#     for i in range(num_lin_imgs):
#         file_path = os.path.join(save_path, f"lin_interp_imgs_{i}.npy")
#         if os.path.exists(file_path):
#             lin_interp_imgs.append(np.load(file_path))
#     lin_interp_imgs = np.concatenate(lin_interp_imgs, axis=0)
#     return lin_interp_imgs

def concatenate_exp_interp_imgs(save_path, num_exp_imgs):
    exp_interp_imgs = []
    for i in range(num_exp_imgs):
        file_path = os.path.join(save_path, f"exp_interp_imgs_{i}.npy")
        if os.path.exists(file_path):
            exp_interp_imgs.append(np.load(file_path))
    exp_interp_imgs = np.concatenate(exp_interp_imgs, axis=0)
    return exp_interp_imgs

# %%
#num_lin_imgs = len(lin_interp_vecs)
num_exp_imgs = len(exp_interp_vecs)

#interp_imgs = concatenate_lin_interp_imgs(save_path, num_lin_imgs)
exp_imgs = concatenate_exp_interp_imgs(save_path, num_exp_imgs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-533605f4fd37> in <cell line: 2>()
#       1 #num_lin_imgs = len(lin_interp_vecs)
# ----> 2 num_exp_imgs = len(exp_interp_vecs)
#       3
#       4 #interp_imgs = concatenate_lin_interp_imgs(save_path, num_lin_imgs)
#       5 exp_imgs = concatenate_exp_interp_imgs(save_path, num_exp_imgs)
#
# NameError: name 'exp_interp_vecs' is not defined

# %% [markdown]
# # Create AV

# %%
def create_video_with_audio(imgs):
    
    # Load the audio file
    audio_clip = mp.AudioFileClip(RAW_AUDIO_PATH)#.set_duration(MAX_VIDEO_DURATION)
    
    # Needed for some reason?
    frames = [mp.ImageClip(img).set_duration(1/FRAME_RATE) for img in imgs]
    
    # Combine the frames into a video clip
    video_clip = mp.concatenate_videoclips(frames, method='chain')
    
    # Overlay the audio on the video clip
    final_clip = video_clip.set_audio(audio_clip)
    
    # Write the final video clip to file
    final_clip.write_videofile("donk.mp4", fps=FRAME_RATE)

# %%
VIDEO_SAVE_PATH

# %%
create_video_with_audio(exp_imgs)

# %%
print(datetime.now() - start)
